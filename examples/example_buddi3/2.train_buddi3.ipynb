# %% [markdown]
# # This notebook demonstrates how to train class version of buddi4 model from buddi_v2

# %%
import os
import joblib

import numpy as np
import pandas as pd

"""Remove line below to use GPU"""
# os.environ["CUDA_VISIBLE_DEVICES"] = "-1"  # This LINE disables GPU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model
from tensorflow.keras.losses import CategoricalCrossentropy, MeanAbsoluteError

# %%
SAMPLE_ID_COL = "sample_id"
STIM_COL = "stim"
GENE_ID_COL = "gene_ids"
TECH_COL = "samp_type"

# %% [markdown]
# ## Add buddi_v2 software to path

# %%
from buddi_v2.dataset.buddi3_dataset import (
    get_supervised_dataset,
    get_unsupervised_dataset,
)
from buddi_v2.models.components.losses import kl_loss
from buddi_v2.models.buddi3_class import BuDDI3
from buddi_v2.models.fit import fit_buddi
from buddi_v2.plotting.plot_loss import plot_loss
from buddi_v2.plotting.plot_latent_space import plot_latent_spaces_buddi

# %% [markdown]
# ## Pre-Processing Output

# %%
## Input data path
import pathlib

REPO_ROOT = pathlib.Path(".")

DATA_PATH = REPO_ROOT / "examples" / "example_data"

if not DATA_PATH.exists():
    raise FileNotFoundError(
        f"Data path {DATA_PATH} does not exist. Please add the example data to the examples/example_data/ directory."
    )

# %% [markdown]
# ### Load train data

# %%
train_data = joblib.load(DATA_PATH / "buddi3_data.pkl")
train_data.reset_query()
train_data
# Out:
# BuDDINData(selected samples=3649/3649, genes=7000, cell_types=8)

# %% [markdown]
# ### Supervised vs Unsupervised split & Dataset Generation

# %%
(X_kp, y_kp, sample_id_kp, samp_type_kp, meta_kp) = (
    train_data.reset_query()
    .query(isTraining="Train", samp_type="sc_ref")
    .get(("X", "y", SAMPLE_ID_COL, TECH_COL, "meta"))
)

(X_unkp, y_unkp, sample_id_unkp, samp_type_unkp, meta_unkp) = (
    train_data.reset_query()
    .query(isTraining="Train", samp_type="bulk")
    .get(("X", "y", SAMPLE_ID_COL, TECH_COL, "meta"))
)

# %% [markdown]
# Generating Tensorflow `dataset` objects for BuDDI4 training (**note** `ds_sup` and `ds_unsup` do not work with plotting or model inference out of the box), use raw data (e.g. `X_kp`, `X_unkp`) instead for these purposes.

# %%
ds_sup = get_supervised_dataset(
    X_known_prop=X_kp,
    Y_known_prop=y_kp,
    label_known_prop=sample_id_kp,
    samp_type_known_prop=samp_type_kp,
)
print(f"Number of entries in supervised dataset: {ds_sup.cardinality().numpy()}")
ds_sup_batch_x, ds_sup_batch_y = next(iter(ds_sup))

ds_unsup = get_unsupervised_dataset(
    X_unknown_prop=X_unkp,
    label_unknown_prop=sample_id_unkp,
    samp_type_unknown_prop=samp_type_unkp,
)
print(f"Number of entries in unsupervised dataset: {ds_unsup.cardinality().numpy()}")

print("\nTake a peek at the dataset generator return:\n")

ds_sup_batch_input, ds_sup_batch_target = next(iter(ds_sup.batch(16).take(1)))
ds_sup_batch_x, ds_sup_batch_y = ds_sup_batch_input
print(f"Supervised batch x shape: {ds_sup_batch_x.shape}")
print(f"Supervised batch y shape: {ds_sup_batch_y.shape}")
(
    ds_sup_batch_target_x,
    _,
    _,
    _,
    ds_sup_batch_label,
    ds_sup_batch_samp_type,
    ds_sup_batch_target_y,
) = ds_sup_batch_target
print(f"Supervised batch target x shape: {ds_sup_batch_target_x.shape}")
print(f"Supervised batch target y shape: {ds_sup_batch_target_y.shape}")
print(f"Supervised batch label shape: {ds_sup_batch_label.shape}")
print(f"Supervised batch samp_type shape: {ds_sup_batch_samp_type.shape}")

print("\n")

ds_unsup_batch_input, ds_unsup_batch_target = next(iter(ds_unsup.batch(16).take(1)))
(ds_unsup_batch_x,) = ds_unsup_batch_input
print(f"Unsupervised batch x shape: {ds_unsup_batch_x.shape}")
ds_unsup_batch_target_x, _, _, _, ds_unsup_batch_label, ds_unsup_batch_samp_type, _ = (
    ds_unsup_batch_target
)
print(f"Unsupervised batch target x shape: {ds_unsup_batch_target_x.shape}")
print(f"Unsupervised batch label shape: {ds_unsup_batch_label.shape}")
print(f"Unsupervised batch samp_type shape: {ds_unsup_batch_samp_type.shape}")
# Out:
# 2026-02-10 16:39:08.746745: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2026-02-10 16:39:08.746773: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 32.00 GB
# 2026-02-10 16:39:08.746791: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 10.67 GB
# 2026-02-10 16:39:08.746809: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-02-10 16:39:08.746825: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Number of entries in supervised dataset: 1800
# Number of entries in unsupervised dataset: 49
#
# Take a peek at the dataset generator return:
#
# Supervised batch x shape: (16, 7000)
# Supervised batch y shape: (16, 8)
# Supervised batch target x shape: (16, 7000)
# Supervised batch target y shape: (16, 8)
# Supervised batch label shape: (16, 51)
# Supervised batch samp_type shape: (16, 2)
#
#
# Unsupervised batch x shape: (16, 7000)
# Unsupervised batch target x shape: (16, 7000)
# Unsupervised batch label shape: (16, 51)
# Unsupervised batch samp_type shape: (16, 2)

# %% [markdown]
# ## BuDDI Training

# %% [markdown]
# ### Instantiate Model

# %%
train_data._encode_fields
# Out:
# ['sample_id', 'samp_type']

# %%
n_x = train_data.shape["X"]
n_y = train_data.shape["y"]
n_sample_ids = train_data.shape["n_sample_id"]
n_samp_types = train_data.shape["n_samp_type"]

# %%
obj = BuDDI3(
    n_x=n_x,
    n_y=n_y,
    z_dim=64,
    encoder_hidden_dim=512,
    decoder_hidden_dim=512,
    activation="relu",
    output_activation="sigmoid",
    n_sample_ids=n_sample_ids,
    n_samp_types=n_samp_types,
)

# %%
obj.print_loss_table()
# Out:
# Loss Name       Function                    Weight
# --------------------------------------------------
# x_hat_sup       MeanAbsoluteError           1.0
# x_hat_unsup     MeanAbsoluteError           1.0
# y_hat           CategoricalCrossentropy     1.0
# y_dummy         unsupervised_dummy_loss_fn  0.0
# kl_sample_id    kl_loss                     1.0
# sample_id_pred  CategoricalCrossentropy     1.0
# kl_samp_type    kl_loss                     1.0
# samp_type_pred  CategoricalCrossentropy     1.0
# kl_slack        kl_loss                     0.1

# %% [markdown]
# ### Configure Losses

# %%
ALPHA = 100.0
ALPHA_X = 1.0

BETA = 100.0
BETA_SAMPLE = 10.0
BETA_SLACK = 0.1

obj.set_reconstruction_loss(
    fn=MeanAbsoluteError(reduction="sum"),
    weight=ALPHA_X,
)
obj.set_encoder_loss(
    branch_name=[TECH_COL],
    fn=kl_loss,
    weight=BETA,
)
obj.set_encoder_loss(
    branch_name=[SAMPLE_ID_COL],
    fn=kl_loss,
    weight=BETA_SAMPLE,
)
obj.set_encoder_loss(
    branch_name="slack",
    fn=kl_loss,
    weight=BETA_SLACK,
)
obj.set_predictor_loss(
    branch_name=[SAMPLE_ID_COL, TECH_COL],
    fn=CategoricalCrossentropy(reduction="sum"),
    weight=ALPHA,
)
obj.set_prop_estimator_loss(
    fn=CategoricalCrossentropy(reduction="sum"),
    weight=ALPHA,
)

obj.print_loss_table()
# Out:
# Loss Name       Function                    Weight
# ---------------------------------------------------
# x_hat_sup       MeanAbsoluteError           1.0
# x_hat_unsup     MeanAbsoluteError           1.0
# y_hat           CategoricalCrossentropy     100.0
# y_dummy         unsupervised_dummy_loss_fn  0.0
# kl_sample_id    kl_loss                     10.0
# sample_id_pred  CategoricalCrossentropy     100.0
# kl_samp_type    kl_loss                     100.0
# samp_type_pred  CategoricalCrossentropy     100.0
# kl_slack        kl_loss                     0.1

# %% [markdown]
# ### Compile

# %%
obj.compile(optimizer=Adam(learning_rate=0.0005))

# %% [markdown]
# ### Visualize connection

# %%
plot_model(
    obj.sup_model,
    show_shapes=True,
    show_layer_names=True,
)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %%
plot_model(
    obj.unsup_model,
    show_shapes=True,
    show_layer_names=True,
)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %%
# !rm model.png
# Out:
# rm: model.png: No such file or directory

# %%
ds_test_sup = None
if train_data.reset_query().query(isTraining="Test", samp_type="sc_ref").__len__() > 0:
    (test_X_kp, test_y_kp, test_sample_id_kp, test_samp_type_kp) = train_data.get(
        ("X", "y", SAMPLE_ID_COL, TECH_COL)
    )

    ds_test_sup = get_supervised_dataset(
        X_known_prop=test_X_kp,
        Y_known_prop=test_y_kp,
        label_known_prop=test_sample_id_kp,
        samp_type_known_prop=test_samp_type_kp,
    )

ds_test_unsup = None
if train_data.reset_query().query(isTraining="Test", samp_type="bulk").__len__() > 0:
    (test_X_unkp, test_y_unkp, test_sample_id_unkp, test_samp_type_unkp) = (
        train_data.get(("X", "y", SAMPLE_ID_COL, TECH_COL))
    )

    ds_test_unsup = get_unsupervised_dataset(
        X_unknown_prop=test_X_unkp,
        label_unknown_prop=test_sample_id_unkp,
        samp_type_unknown_prop=test_samp_type_unkp,
    )

# %% [markdown]
# ### Train Model

# %%
all_loss_df = fit_buddi(
    supervised_model=obj.sup_model,
    unsupervised_model=obj.unsup_model,
    dataset_supervised=ds_sup,
    dataset_unsupervised=ds_unsup,
    dataset_test_supervised=ds_test_sup,
    dataset_test_unsupervised=ds_test_unsup,
    epochs=10,
    batch_size=16,
    shuffle_every_epoch=True,
    prefetch=False,
)
# Out:
# Epoch 1/10:   0%|                                                                                                                                                                      | 0/113 [00:00<?, ?it/s]2026-02-10 16:39:17.491673: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# Epoch 1/10: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:51<00:00,  1.68s/it]2026-02-10 16:40:02.050342: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 1/10: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:51<00:00,  2.19it/s]
# Testing supervised model: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:10<00:00,  5.21it/s]2026-02-10 16:40:12.444506: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Testing supervised model: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:10<00:00, 10.91it/s]
# Epoch 2/10: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:24<00:00,  5.04it/s]2026-02-10 16:40:36.562012: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 2/10: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:24<00:00,  4.69it/s]
# Testing supervised model:  99%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋ | 112/113 [00:08<00:00, 13.74it/s]2026-02-10 16:40:45.474409: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Testing supervised model: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:08<00:00, 12.71it/s]
# Epoch 3/10: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:22<00:00,  4.73it/s]2026-02-10 16:41:08.200786: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 3/10: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:22<00:00,  4.98it/s]
# Testing supervised model: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:08<00:00, 14.10it/s]2026-02-10 16:41:17.104087: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Testing supervised model: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:08<00:00, 12.73it/s]
# Epoch 4/10: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:23<00:00,  5.46it/s]2026-02-10 16:41:40.197922: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 4/10: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:23<00:00,  4.90it/s]
# Testing supervised model: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:09<00:00, 13.94it/s]2026-02-10 16:41:49.416208: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Testing supervised model: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:09<00:00, 12.28it/s]
# Epoch 5/10: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:24<00:00,  5.49it/s]2026-02-10 16:42:14.090074: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 5/10: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:24<00:00,  4.59it/s]
# Testing supervised model: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:09<00:00, 12.35it/s]2026-02-10 16:42:23.236114: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Testing supervised model: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:09<00:00, 12.38it/s]
# Epoch 6/10: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:24<00:00,  5.52it/s]2026-02-10 16:42:47.301769: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 6/10: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:24<00:00,  4.70it/s]
# Testing supervised model: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:08<00:00, 13.36it/s]2026-02-10 16:42:55.921881: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Testing supervised model: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:08<00:00, 13.15it/s]
# Epoch 7/10: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:26<00:00,  4.94it/s]2026-02-10 16:43:22.175752: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 7/10: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:26<00:00,  4.31it/s]
# Testing supervised model: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:09<00:00, 13.19it/s]2026-02-10 16:43:31.805509: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Testing supervised model: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:09<00:00, 11.77it/s]
# Epoch 8/10: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:23<00:00,  4.78it/s]2026-02-10 16:43:55.611588: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 8/10: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:23<00:00,  4.75it/s]
# Testing supervised model: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:09<00:00, 12.98it/s]2026-02-10 16:44:04.793110: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Testing supervised model: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:09<00:00, 12.33it/s]
# Epoch 9/10: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:24<00:00,  4.79it/s]2026-02-10 16:44:29.034056: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 9/10: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:24<00:00,  4.66it/s]
# Testing supervised model: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:09<00:00, 13.22it/s]2026-02-10 16:44:38.432362: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Testing supervised model: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:09<00:00, 12.07it/s]
# Epoch 10/10: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:23<00:00,  5.53it/s]2026-02-10 16:45:01.919603: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 10/10: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:23<00:00,  4.81it/s]
# Testing supervised model: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:08<00:00, 14.56it/s]2026-02-10 16:45:10.556438: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Testing supervised model: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:08<00:00, 13.11it/s]
# Training complete!

# %%
all_loss_df.head()
# Out:
#            loss  X_reconstruction_loss  encoder_sample_id_loss  \
# 0  15097.149414               5.365099               34.908112
# 1  32688.751953               5.508605              314.657410
# 2  35551.175781               5.262549              383.442780
# 3  37146.058594               4.957957              454.219116
# 4  35919.347656               4.694110              452.917633
#
#    encoder_samp_type_loss  encoder_slack_loss  classifier_sample_id_loss  \
# 0               33.218346           41.198822                  77.220535
# 1              140.060944          142.844543                  47.436581
# 2              156.699814          153.193924                  35.256893
# 3              173.752625          158.000198                  26.886150
# 4              168.203308          144.940582                  22.112452
#
#    classifier_samp_type_loss  prop_estimator_loss  epoch  batch        type  \
# 0                   2.016035            34.930916      0      0  supervised
# 1                   2.429889           105.296448      0      1  supervised
# 2                   8.510577           116.494385      0      2  supervised
# 3                   7.780648           117.411674      0      3  supervised
# 4                   6.414911           116.979149      0      4  supervised
#
#    split
# 0  train
# 1  train
# 2  train
# 3  train
# 4  train

# %% [markdown]
# ### Examine Reconstruction
#
# **Optional**: For seeded deterministic behavior, do:
# ```python
# obj.set_reparam_deterministic(deterministic=True, seed=42)
# ```
# To go back to stochastic, simply do:
# ```python
# obj.set_reparam_deterministic(deterministic=False)
# ```

# %%
(
    x_hat,
    z_param_label,
    z_param_samp_type,
    z_param_slack,
    pred_label,
    pred_samp_type,
    y_hat,
) = obj.unsup_model(ds_unsup_batch_input)
print(f"Predicted x shape: {x_hat.shape}")
print(f"Predicted z_param_label shape: {z_param_label.shape}")
print(f"Predicted z_param_samp_type shape: {z_param_samp_type.shape}")
print(f"Predicted z_param_slack shape: {z_param_slack.shape}")
print(f"Predicted pred_label shape: {pred_label.shape}")
print(f"Predicted pred_samp_type shape: {pred_samp_type.shape}")
print(f"Predicted y_hat shape: {y_hat.shape}")
# Out:
# Predicted x shape: (16, 7000)
# Predicted z_param_label shape: (16, 128)
# Predicted z_param_samp_type shape: (16, 128)
# Predicted z_param_slack shape: (16, 128)
# Predicted pred_label shape: (16, 51)
# Predicted pred_samp_type shape: (16, 2)
# Predicted y_hat shape: (16, 8)

# %% [markdown]
# ### Visualize latent space of Train

# %%
# Down-sample the sc_ref and bulk data for visualization
(X_kp_tmp, Y_kp_tmp, meta_kp_tmp) = (
    train_data.reset_query()
    .query(isTraining="Train", samp_type="sc_ref")
    .get(("X", "y", "meta"), n_samples=500, replace=True, random_state=42)
)

(X_unkp_tmp, Y_unkp_tmp, meta_unkp_tmp) = (
    train_data.reset_query()
    .query(isTraining="Train", samp_type="bulk")
    .get(("X", "y", "meta"), n_samples=500, replace=True, random_state=42)
)

cell_types = train_data.cell_type_names
X_tmp = np.concatenate((X_kp_tmp, X_unkp_tmp), axis=0)
Y_tmp = np.concatenate((Y_kp_tmp, Y_unkp_tmp), axis=0)
meta_tmp = pd.concat((meta_kp_tmp, meta_unkp_tmp), axis=0)


idx_sc_prop = np.where(meta_tmp.cell_prop_type == "single_celltype")[0]
cell_type_labels = [cell_types[i] for i in np.argmax(Y_tmp[idx_sc_prop, :], axis=1)]
cell_type_col = meta_tmp.loc[:, "cell_prop_type"].values.copy()
cell_type_col[idx_sc_prop] = cell_type_labels
meta_tmp.loc[:, "cell_type"] = cell_type_col

_ = plot_latent_spaces_buddi(
    obj,
    X_tmp=X_tmp,
    meta_tmp=meta_tmp,
    type="PCA",
    panel_width=5,
    show_plot=True,
    save_path=None,
)

# %% [markdown]
# ### Visualize latent space don't filter by split

# %%
(X_kp_tmp, Y_kp_tmp, meta_kp_tmp) = (
    train_data.reset_query()
    .query(samp_type="sc_ref")
    .get(("X", "y", "meta"), n_samples=500, replace=True, random_state=42)
)

(X_unkp_tmp, Y_unkp_tmp, meta_unkp_tmp) = (
    train_data.reset_query()
    .query(samp_type="bulk")
    .get(("X", "y", "meta"), n_samples=500, replace=True, random_state=42)
)

cell_types = train_data.cell_type_names
X_tmp = np.concatenate((X_kp_tmp, X_unkp_tmp), axis=0)
Y_tmp = np.concatenate((Y_kp_tmp, Y_unkp_tmp), axis=0)
meta_tmp = pd.concat((meta_kp_tmp, meta_unkp_tmp), axis=0)


idx_sc_prop = np.where(meta_tmp.cell_prop_type == "single_celltype")[0]
cell_type_labels = [cell_types[i] for i in np.argmax(Y_tmp[idx_sc_prop, :], axis=1)]
cell_type_col = meta_tmp.loc[:, "cell_prop_type"].values.copy()
cell_type_col[idx_sc_prop] = cell_type_labels
meta_tmp.loc[:, "cell_type"] = cell_type_col

_ = plot_latent_spaces_buddi(
    obj,
    X_tmp=X_tmp,
    meta_tmp=meta_tmp,
    type="PCA",
    panel_width=5,
    show_plot=True,
    save_path=None,
)

# %% [markdown]
# ### Plot Train Loss

# %%
plot_loss(all_loss_df, save_path=None, show_plot=True)

# %% [markdown]
# ### Saving BuDDI3 object

# %%
obj.save(directory="temp")

# %% [markdown]
# Saved model structure looks like this

# %%
print(os.listdir("temp"))
# Out:
# ['samp_type_classifier.weights.h5', 'slack_encoder.weights.h5', 'sample_id_classifier.weights.h5', 'config.json', 'prop_estimator.weights.h5', 'samp_type_encoder.weights.h5', 'sample_id_encoder.weights.h5', 'decoder.weights.h5']

# %%
# !rm -rf temp

# %% [markdown]
# ### To load saved object and weights, do

# %%
# loaded_obj = BuDDI3.load(
#     directory='temp'
# )
